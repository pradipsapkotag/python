# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %%
data_url = 'https://github.com/pradipsapkotag/python/blob/pandas/Assignment1/10_Deleting/Iris/iris.csv'

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris = df.copy()

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

# %%
iris.columns = ["sepal_length (in cm)", 'sepal_width (in cm)', 'petal_length (in cm)', 'petal_width (in cm)', 'class']

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# ...

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isnull().sum()
# Out:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:20,'petal_length (in cm)':]
# Out:
#     petal_length (in cm)  petal_width (in cm)        class
# 10                   1.6                  0.2  Iris-setosa
# 11                   1.4                  0.1  Iris-setosa
# 12                   1.1                  0.1  Iris-setosa
# 13                   1.2                  0.2  Iris-setosa
# 14                   1.5                  0.4  Iris-setosa
# 15                   1.3                  0.4  Iris-setosa
# 16                   1.4                  0.3  Iris-setosa
# 17                   1.7                  0.3  Iris-setosa
# 18                   1.5                  0.3  Iris-setosa
# 19                   1.7                  0.2  Iris-setosa
# 20                   1.5                  0.4  Iris-setosa

# %%
iris['petal_length (in cm)'][10:29] = np.nan
# Out:
# /tmp/ipykernel_7305/4208286805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iris['petal_length (in cm)'][10:29] = np.nan

# %%
iris.loc[5:35]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   NaN
# 11                   4.8                  3.0                   NaN
# 12                   4.3                  3.0                   NaN
# 13                   5.8                  4.0                   NaN
# 14                   5.7                  4.4                   NaN
# 15                   5.4                  3.9                   NaN
# 16                   5.1                  3.5                   NaN
# 17                   5.7                  3.8                   NaN
# ...

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris = iris.replace(np.nan, 1.0)

# %%
iris.loc[5:35]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   1.0
# 11                   4.8                  3.0                   1.0
# 12                   4.3                  3.0                   1.0
# 13                   5.8                  4.0                   1.0
# 14                   5.7                  4.4                   1.0
# 15                   5.4                  3.9                   1.0
# 16                   5.1                  3.5                   1.0
# 17                   5.7                  3.8                   1.0
# ...

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris = iris.drop(columns = 'class')

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# 1                    0.2
# 2                    0.2
# 3                    0.2
# ...

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[:3] = np.nan

# %%
iris.head(10)
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
# 5                   4.6                  3.4                   1.4
# 6                   5.0                  3.4                   1.5
# 7                   4.4                  2.9                   1.4
# 8                   4.9                  3.1                   1.5
# 9                   5.4                  3.7                   1.5
#
#    petal_width (in cm)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  0.2
# 4                  0.4
# 5                  0.3
# 6                  0.2
# 7                  0.2
# ...

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris = iris.dropna(axis=0)

# %%
iris.head(10)
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                    5.0                  3.6                   1.4
# 4                    5.4                  3.9                   1.7
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   1.0
# 11                   4.8                  3.0                   1.0
# 12                   4.3                  3.0                   1.0
#
#     petal_width (in cm)
# 3                   0.2
# 4                   0.4
# 5                   0.3
# 6                   0.2
# 7                   0.2
# 8                   0.1
# 9                   0.2
# ...

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop = True, inplace = True)

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.0                  3.6                   1.4
# 1                     5.4                  3.9                   1.7
# 2                     4.6                  3.4                   1.4
# 3                     5.0                  3.4                   1.5
# 4                     4.4                  2.9                   1.4
# ..                    ...                  ...                   ...
# 141                   6.7                  3.0                   5.2
# 142                   6.3                  2.5                   5.0
# 143                   6.5                  3.0                   5.2
# 144                   6.2                  3.4                   5.4
# 145                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# 1                    0.4
# 2                    0.3
# 3                    0.2
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
del iris['sepal_width (in cm)']

# %%
iris.head(10)
# Out:
#    sepal_length (in cm)  petal_length (in cm)  petal_width (in cm)
# 0                   5.0                   1.4                  0.2
# 1                   5.4                   1.7                  0.4
# 2                   4.6                   1.4                  0.3
# 3                   5.0                   1.5                  0.2
# 4                   4.4                   1.4                  0.2
# 5                   4.9                   1.5                  0.1
# 6                   5.4                   1.5                  0.2
# 7                   4.8                   1.0                  0.2
# 8                   4.8                   1.0                  0.1
# 9                   4.3                   1.0                  0.1
